# %% [markdown]
# # <h2>NABATANZI GORRET</h2>

# %% [markdown]
# # Final Exam
#
# # Background on Python, iPython, Jupyter and Pandas
#
# [Python](https://www.python.org/) is a high-level general purpose programming language named after a [British comedy troup](https://www.youtube.com/user/MontyPython), created by a [Dutch programmer as a hobby project](http://en.wikipedia.org/wiki/Guido_van_Rossum) and maintained by an international group of friendly but opinionated python enthusiasts (`import this!`). Until June 2018, Guido van Rossum was the [Benevolent dictator for life](https://en.wikipedia.org/wiki/Benevolent_dictator_for_life) for the Python language, now decisions are made jointly by the Python Steering Council.
#
# Python is popular for data science because it's powerful, fast, plays well with others, runs everywhere, is easy to learn, highly readable, and open. Because it's general purpose it can be used for full-stack development. It's got a growing list of useful libraries for scientitic programming, data manipulation, data analysis. (Numpy, Scipy, Pandas, Scikit-Learn, Statsmodels, Matplotlib, Pybrain, etc.)
#
# [iPython](http://ipython.org/) is an enhanced, interactive python interpreter started as a grad school project by [Fernando Perez](http://fperez.org/). iPython (jupyter) notebooks allow you to run a multi-language (Python, R, Julia, Markdown, LaTex, etc) interpreter in your browser to create rich, portable, and sharable code documents.
#
# [Pandas](http://pandas.pydata.org/) is a libary created by [Wes McKinney](http://blog.wesmckinney.com/) that introduces the R-like dataframe object to Python and makes working with data in Python a lot easier. It's also a lot more efficient than the R dataframe and pretty much makes Python superior to R in every imaginable way (except for ggplot 2).
#
#
# # Final Exam
#
# This self-grading notebook serves as a final exam for the introductory course.
# If you have grasped the contents of the course, you should be able to complete
# this exam.
#
# It is essential that you answer each cell by assigning the solution to `QUESTION_#`
# where `#` is the question number.
#
# We will start with a warm-up question that is already answered.
#
# ## Getting started with Jupyter (iPython) Notebooks
#
# To start up a Jupyter notebook server, simply navigate to the directory where you want the notebooks to be saved and run the command
#
# ```
# jupyter notebook
# ```
#
# A browser should open with a notebook navigator. Click the "New" button and select "Python 3".
#
# A beautiful blank notebook should open in a new tab
#
# Name the notebook by clicking on "Untitled" at the top of the page.
#
# Notebooks are squences of cells. Cells can be markdown, code, or raw text. Change the first cell to markdown and briefly describe what you are going to do in the notebook.
#
# ## Getting started with Pandas
#
# We start by importing the libraries we're going to use any library in the notebook:E.G., `pandas` and `matplotlib`, `seaborn`, `Numpy`, `Statsmodels`
#
#
#
# ## Question 0
#
# Create a 3-element 1-dimensional array containing the values [1,1,1]
#
# _Note_: This answer is not assessed.

# %%
# Import Statements that might be of use
import pandas as pd
import numpy as np
# %matplotlib inline
import datetime
# import math
# import requests
# from bs4 import BeautifulSoup
# # from selenium import webdriver
# import dateutil.parser
# import time
# import re
# import statsmodels.api as sm
# import statsmodels.formula.api as smf
# import sklearn
# from tqdm import tqdm_notebook
# from collections import defaultdict

# %%
QUESTION_0 = np.array([1,1,1]) 
QUESTION_0
# Out:
# array([1, 1, 1])

# %% [markdown]
# ## Accessing Documentation with ``?``
#
# The Python language and its data science ecosystem is built with the user in mind, and one big part of that is access to documentation.
# Every Python object contains the reference to a string, known as a *doc string*, which in most cases will contain a concise summary of the object and how to use it.
# Python has a built-in ``help()`` function that can access this information and prints the results.
# For example, to see the documentation of the built-in ``len`` function, you can do the following:
#
# ```ipython
# In [1]: help(len)
# Help on built-in function len in module builtins:
#
# len(...)
#     len(object) -> integer
#
#     Return the number of items of a sequence or mapping.
# ```
#
# Depending on your interpreter, this information may be displayed as inline text, or in some separate pop-up window.

# %% [markdown]
# ## Loading data into a Pandas DataFrame
#
# So far we've been working with many datasets and raw files during our class sessions. This functions below should be familiar for your to apply through out the exam
#
# Built-in Data Structures
# - strings ""
# - lists []
# - tuples ()
# - sets {}
# - dictionaries {'key':value}
#
# Additional Essential Data Structures
#
# - numpy arrays ([])
# - pandas Series
# - pandas DataFrame
# - tensorflow Tensors
#
#
# Today we'll primarily be working with the pandas DataFrame. The pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes. It's basically a spreadsheet you can program and it's an incredibly useful Python object for data analysis.
#
# You can load data into a dataframe using Pandas' excellent `read_*` functions.
#
# We're going to try two of them: read_table & read_csv
#
# Pro tip: TAB COMPLETION!
#
# Pro tip: jupyter will pull the doc string for a command just by asking it a question.
#
# Pro tip: jupyter will give you the allowable arguments if you hit `shift + tab`

# %% [markdown]
# ## Question 1 (a) (i)
#
# Construct the correlation matrix
#
# $$\left[\begin{array}{ccc} 1 & 0.2 & 0.5 \\ 0.2 & 1 & 0.8 \\ 0.5 & 0.8 & 1 \end{array}\right]$$
#
# as a NumPy array.

# %%
#let the correlatio matrix be m
m = np.array([[1,0.2,0.5],[0.2,1,0.8],[0.5,0.8,1]])
#printing the matrix m
print(m)
# Out:
# [[1.  0.2 0.5]
#  [0.2 1.  0.8]
#  [0.5 0.8 1. ]]

# %% [markdown]
# ## (ii)
#  Construct the correlation matrix
#
# $$\left[\begin{array}{ccc} 1 & 0.2 & 0.5 \\ 0.2 & 1 & 0.8 \\ 0.5 & 0.8 & 1 \end{array}\right]$$
#
# as a DataFrame with columns and index both equal to `['A', 'B', 'C']`.

# %%
#let df be the dataframe for the correlation matrix
df = pd.DataFrame(m,columns=["A","B","C"],index=["A","B","C"])
#displaying the dataframe
df
# Out:
#      A    B    C
# A  1.0  0.2  0.5
# B  0.2  1.0  0.8
# C  0.5  0.8  1.0

# %% [markdown]
# ## Question 1 (iii)
#
# Load the momentum data in the CSV file `momentum.csv`, set the column `date`
# as the index, and ensure that `date` is a `DateTimeIndex`.

# %%
#Momentum Results, loading the file from my directory and setting the date to datetimeindex and indexing it at once using parse_dates=['date'], index_col=['date']
momentumData = pd.read_csv(r'C:\Users\golden\Desktop\ds\Final Data Science Exam\momentum.csv',parse_dates=['date'], index_col=['date'])
momentumData
# Out:
#             mom_01  mom_02  mom_03  mom_04  mom_05  mom_06  mom_07  mom_08  \
# date
# 2016-01-04    0.67   -0.03   -0.93   -1.11   -1.47   -1.66   -1.40   -2.08
# 2016-01-05   -0.36    0.20   -0.37    0.28    0.16    0.18   -0.22    0.25
# 2016-01-06   -4.97   -2.33   -2.60   -1.16   -1.70   -1.45   -1.15   -1.46
# 2016-01-07   -4.91   -1.91   -3.03   -1.87   -2.31   -2.30   -2.70   -2.31
# 2016-01-08   -0.40   -1.26   -0.98   -1.26   -1.13   -1.02   -0.96   -1.42
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2017-12-22    0.24    0.13   -0.07   -0.01   -0.08   -0.10   -0.14   -0.16
# 2017-12-26    0.89    0.70    0.23   -0.03    0.10   -0.06   -0.14   -0.07
# 2017-12-27   -0.58   -0.55   -0.27   -0.19   -0.14    0.18    0.18    0.10
# 2017-12-28    0.14    0.23    0.32    0.02    0.29    0.16    0.30    0.15
# 2017-12-29   -0.42   -0.61   -0.48   -0.57   -0.45   -0.41   -0.52   -0.45
#
#             mom_09  mom_10
# date
# 2016-01-04   -1.71   -2.67
# 2016-01-05    0.29    0.13
# 2016-01-06   -1.14   -0.45
# 2016-01-07   -2.36   -2.66
# 2016-01-08   -0.94   -1.32
# ...            ...     ...
# 2017-12-22   -0.05   -0.01
# 2017-12-26    0.14   -0.65
# 2017-12-27    0.22    0.36
# 2017-12-28    0.28    0.29
# 2017-12-29   -0.70   -0.94
#
# [503 rows x 10 columns]

# %%
#Confirming that thr date is a datetimeindex using the info() method
momentumData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 503 entries, 2016-01-04 to 2017-12-29
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mom_01  503 non-null    float64
#  1   mom_02  503 non-null    float64
#  2   mom_03  503 non-null    float64
#  3   mom_04  503 non-null    float64
#  4   mom_05  503 non-null    float64
#  5   mom_06  503 non-null    float64
#  6   mom_07  503 non-null    float64
#  7   mom_08  503 non-null    float64
#  8   mom_09  503 non-null    float64
#  9   mom_10  503 non-null    float64
# dtypes: float64(10)
# memory usage: 43.2 KB

# %% [markdown]
# ## Question 1 (iv) ##
#
# (a). Construct a DataFrame using the data loaded in the previous question 1 (iii)
# that contains the returns from momentum portfolio 5 in March and April 2016.
#
# (b). Load another data in the csv file `crimes.csv`and modify it into a dataframe using:
#
# HINT:Notice that that has some issues when it comes to column names. Your are required to fix the issues by editing, monipulating and probably deleting some clumns columns.:
#
# The expected solutions and cleaned data should implement:
#
# 1. Remove white spaces
#
# 2. Replacing spaces with underscore
#
# 3. You should also remove the double occurence of "_" in DATE__OF_OCCURENCE. Do so below:
#
# 4. Write code to drop column 'Location':
#
# 5. Once cleaned, we would like you to describe the better global view of the dataset. By writing code to describe, generate a sum (of null).
#
# 6. Select and subsett in pandas using: `''` or quote methods or .head methods on PRIMARY_DESCRIPTION column
#
# 7. Obtain the value counts for PRIMARY_DESCRIPTION column
#
# 8. selecting two columns: enter code to select two columns. It will look something like: dataframe[[column 1, column 2]] for
# 'PRIMARY_DESCRIPTION', 'SECONDARY_DESCRIPTION']] and view only the few columns (first ten),then subset by row index also for the first ten (3:10)
#
# 9. Data Sorting: Write code to sort values for theft column according to the date of occurance, in ascending and make use of inplace function argument. `HINT: You may realise that the something is not right especially the way the sort function is sorting the data. If your are convinced by this statement. Ensure that the date objects are handled well`.
#
# 10. Finally apply `Functions to series` use `Group by` year and month to look at data on a month to month basis.

# %%
#Part a
#Obtaining the momentum portifolio data 5 , given the varriable momentum_5_data
momentum_5_data = momentumData['mom_05']
momentum_5_data
# Out:
# date
# 2016-01-04   -1.47
# 2016-01-05    0.16
# 2016-01-06   -1.70
# 2016-01-07   -2.31
# 2016-01-08   -1.13
#               ...
# 2017-12-22   -0.08
# 2017-12-26    0.10
# 2017-12-27   -0.14
# 2017-12-28    0.29
# 2017-12-29   -0.45
# Name: mom_05, Length: 503, dtype: float64

# %%
#Extracting data in March and April in 2016 for momentum 5, let it be df
df = momentum_5_data[momentum_5_data.index.month.isin([3,4]) & momentum_5_data.index.year.isin([2016])]
df
# Out:
# date
# 2016-03-01    2.61
# 2016-03-02    0.58
# 2016-03-03    0.71
# 2016-03-04    0.73
# 2016-03-07    0.63
# 2016-03-08   -1.97
# 2016-03-09    0.34
# 2016-03-10    0.00
# 2016-03-11    2.08
# 2016-03-14   -0.09
# 2016-03-15   -0.04
# 2016-03-16    0.61
# 2016-03-17    0.68
# 2016-03-18    0.87
# 2016-03-21    0.20
# 2016-03-22   -0.11
# 2016-03-23   -1.11
# 2016-03-24   -0.21
# 2016-03-28   -0.05
# 2016-03-29    0.98
# 2016-03-30    0.69
# 2016-03-31   -0.17
# 2016-04-01    0.39
# 2016-04-04   -0.08
# 2016-04-05   -1.09
# 2016-04-06    1.49
# 2016-04-07   -1.51
# 2016-04-08    0.10
# 2016-04-11    0.00
# 2016-04-12    1.37
# 2016-04-13    1.64
# 2016-04-14   -0.08
# 2016-04-15   -0.70
# 2016-04-18    0.10
# 2016-04-19    0.25
# 2016-04-20    0.73
# 2016-04-21   -0.37
# 2016-04-22    0.51
# 2016-04-25   -0.29
# 2016-04-26    0.35
# 2016-04-27   -1.04
# 2016-04-28   -1.33
# 2016-04-29   -1.43
# Name: mom_05, dtype: float64

# %%
#Part b
#Crimes data, loading the dataset and displaying it
crimesData = pd.read_csv(r'C:\Users\golden\Desktop\ds\Final Data Science Exam\chicago_past_year_crimes.csv')
crimesData
# Out:
#            CASE#     DATE  OF OCCURRENCE                   BLOCK  IUCR  \
# 0       JB241987  04/28/2018 10:05:00 PM        009XX N LONG AVE  2092
# 1       JA430240  09/06/2017 01:30:00 PM         032XX W 26TH ST  0810
# 2       JB241350  04/28/2018 08:00:00 AM         008XX E 53RD ST  1320
# 3       JB245397  04/28/2018 09:00:00 AM    062XX S MICHIGAN AVE  0820
# 4       JB241444  04/28/2018 12:15:00 PM      046XX N ELSTON AVE  0890
# ...          ...                     ...                     ...   ...
# 261959  JA385552  08/10/2017 10:30:00 AM         048XX W IOWA ST  1310
# 261960  JA492228  10/30/2017 04:00:00 PM  072XX S SOUTH SHORE DR  0810
# 261961  JA390514  08/13/2017 08:00:00 PM    039XX W VAN BUREN ST  0910
# 261962  JA385930  08/10/2017 04:00:00 AM     071XX S WOLCOTT AVE  1305
# 261963  JA536019  12/02/2017 08:00:00 PM     083XX S INDIANA AVE  1320
#
#         PRIMARY DESCRIPTION           SECONDARY DESCRIPTION  \
# 0                 NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY
# 1                     THEFT                       OVER $500
# 2           CRIMINAL DAMAGE                      TO VEHICLE
# 3                     THEFT                  $500 AND UNDER
# 4                     THEFT                   FROM BUILDING
# ...                     ...                             ...
# 261959      CRIMINAL DAMAGE                     TO PROPERTY
# 261960                THEFT                       OVER $500
# 261961  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 261962      CRIMINAL DAMAGE             CRIMINAL DEFACEMENT
# 261963      CRIMINAL DAMAGE                      TO VEHICLE
#
#            LOCATION DESCRIPTION ARREST DOMESTIC  BEAT  WARD FBI CD  \
# 0                      SIDEWALK      Y        N  1524  37.0     18
# 1                         OTHER      Y        N  1024  12.0     06
# 2                        STREET      N        N   233   5.0     14
# 3       RESIDENCE PORCH/HALLWAY      N        N   311  20.0     06
# 4            SMALL RETAIL STORE      N        N  1722  39.0     06
# ...                         ...    ...      ...   ...   ...    ...
# 261959                RESIDENCE      N        N  1531  37.0     14
# 261960                APARTMENT      N        Y   334   7.0     06
# 261961                   STREET      N        N  1132  24.0     07
# 261962                RESIDENCE      N        N   735  17.0     14
# 261963                   STREET      N        N   632   6.0     14
#
#         X COORDINATE  Y COORDINATE   LATITUDE  LONGITUDE  \
# 0          1140136.0     1905903.0  41.897895 -87.760744
# 1          1155313.0     1886555.0  41.844510 -87.705519
# 2          1182892.0     1870055.0  41.798635 -87.604823
# 3          1178263.0     1863570.0  41.780946 -87.621995
# 4          1146646.0     1930549.0  41.965404 -87.736202
# ...              ...           ...        ...        ...
# 261959     1143912.0     1905538.0  41.896823 -87.746884
# 261960     1194878.0     1857803.0  41.764728 -87.561272
# 261961     1150218.0     1897735.0  41.875290 -87.723926
# 261962     1164921.0     1857378.0  41.764247 -87.671085
# 261963     1179046.0     1849699.0  41.742865 -87.619547
#
#                              LOCATION
# 0       (41.897894893, -87.760743714)
# 1       (41.844510467, -87.705519454)
# 2       (41.798635468, -87.604823241)
# 3       (41.780946398, -87.621995369)
# 4       (41.965404069, -87.736202402)
# ...                               ...
# 261959     (41.8968233, -87.74688383)
# 261960  (41.764728045, -87.561272312)
# 261961  (41.875290412, -87.723926225)
# 261962  (41.764247182, -87.671084615)
# 261963  (41.742865052, -87.619546732)
#
# [261964 rows x 17 columns]

# %%
#Part b
#Analysing the columns to easily notice what is required and how the initial columns are structured
crimesData.columns
# Out:
# Index(['CASE#', 'DATE  OF OCCURRENCE', 'BLOCK', ' IUCR',
#        ' PRIMARY DESCRIPTION', ' SECONDARY DESCRIPTION',
#        ' LOCATION DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT', 'WARD', 'FBI CD',
#        'X COORDINATE', 'Y COORDINATE', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
#Part b
#Renaming the columns through removing whitespaces and placing underscores with space and displaying the new dataframe
crimesData.rename(columns={"DATE  OF OCCURRENCE": "DATE_OF_OCCURENCE"," IUCR": "IUCR",' PRIMARY DESCRIPTION':'PRIMARY_DESCRIPTION',' SECONDARY DESCRIPTION':'SECONDARY_DESCRIPTION', ' LOCATION DESCRIPTION':'LOCATION_DESCRIPTION','FBI CD':'FBI_CD','X COORDINATE':'X_COORDINATE','Y COORDINATE':'Y_COORDINATE'},inplace=True)
crimesData
# Out:
#            CASE#       DATE_OF_OCCURENCE                   BLOCK  IUCR  \
# 0       JB241987  04/28/2018 10:05:00 PM        009XX N LONG AVE  2092
# 1       JA430240  09/06/2017 01:30:00 PM         032XX W 26TH ST  0810
# 2       JB241350  04/28/2018 08:00:00 AM         008XX E 53RD ST  1320
# 3       JB245397  04/28/2018 09:00:00 AM    062XX S MICHIGAN AVE  0820
# 4       JB241444  04/28/2018 12:15:00 PM      046XX N ELSTON AVE  0890
# ...          ...                     ...                     ...   ...
# 261959  JA385552  08/10/2017 10:30:00 AM         048XX W IOWA ST  1310
# 261960  JA492228  10/30/2017 04:00:00 PM  072XX S SOUTH SHORE DR  0810
# 261961  JA390514  08/13/2017 08:00:00 PM    039XX W VAN BUREN ST  0910
# 261962  JA385930  08/10/2017 04:00:00 AM     071XX S WOLCOTT AVE  1305
# 261963  JA536019  12/02/2017 08:00:00 PM     083XX S INDIANA AVE  1320
#
#         PRIMARY_DESCRIPTION           SECONDARY_DESCRIPTION  \
# 0                 NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY
# 1                     THEFT                       OVER $500
# 2           CRIMINAL DAMAGE                      TO VEHICLE
# 3                     THEFT                  $500 AND UNDER
# 4                     THEFT                   FROM BUILDING
# ...                     ...                             ...
# 261959      CRIMINAL DAMAGE                     TO PROPERTY
# 261960                THEFT                       OVER $500
# 261961  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 261962      CRIMINAL DAMAGE             CRIMINAL DEFACEMENT
# 261963      CRIMINAL DAMAGE                      TO VEHICLE
#
#            LOCATION_DESCRIPTION ARREST DOMESTIC  BEAT  WARD FBI_CD  \
# 0                      SIDEWALK      Y        N  1524  37.0     18
# 1                         OTHER      Y        N  1024  12.0     06
# 2                        STREET      N        N   233   5.0     14
# 3       RESIDENCE PORCH/HALLWAY      N        N   311  20.0     06
# 4            SMALL RETAIL STORE      N        N  1722  39.0     06
# ...                         ...    ...      ...   ...   ...    ...
# 261959                RESIDENCE      N        N  1531  37.0     14
# 261960                APARTMENT      N        Y   334   7.0     06
# 261961                   STREET      N        N  1132  24.0     07
# 261962                RESIDENCE      N        N   735  17.0     14
# 261963                   STREET      N        N   632   6.0     14
#
#         X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE  \
# 0          1140136.0     1905903.0  41.897895 -87.760744
# 1          1155313.0     1886555.0  41.844510 -87.705519
# 2          1182892.0     1870055.0  41.798635 -87.604823
# 3          1178263.0     1863570.0  41.780946 -87.621995
# 4          1146646.0     1930549.0  41.965404 -87.736202
# ...              ...           ...        ...        ...
# 261959     1143912.0     1905538.0  41.896823 -87.746884
# 261960     1194878.0     1857803.0  41.764728 -87.561272
# 261961     1150218.0     1897735.0  41.875290 -87.723926
# 261962     1164921.0     1857378.0  41.764247 -87.671085
# 261963     1179046.0     1849699.0  41.742865 -87.619547
#
#                              LOCATION
# 0       (41.897894893, -87.760743714)
# 1       (41.844510467, -87.705519454)
# 2       (41.798635468, -87.604823241)
# 3       (41.780946398, -87.621995369)
# 4       (41.965404069, -87.736202402)
# ...                               ...
# 261959     (41.8968233, -87.74688383)
# 261960  (41.764728045, -87.561272312)
# 261961  (41.875290412, -87.723926225)
# 261962  (41.764247182, -87.671084615)
# 261963  (41.742865052, -87.619546732)
#
# [261964 rows x 17 columns]

# %%
#Part 4 Dropping the column Location Description which is an index of 6 using inplace to true for this dataframe without creating a new dataframe if inplace was false
crimesData.drop(crimesData.columns[6],axis=1,inplace=True)
crimesData
# Out:
#            CASE#       DATE_OF_OCCURENCE                   BLOCK  IUCR  \
# 0       JB241987  04/28/2018 10:05:00 PM        009XX N LONG AVE  2092
# 1       JA430240  09/06/2017 01:30:00 PM         032XX W 26TH ST  0810
# 2       JB241350  04/28/2018 08:00:00 AM         008XX E 53RD ST  1320
# 3       JB245397  04/28/2018 09:00:00 AM    062XX S MICHIGAN AVE  0820
# 4       JB241444  04/28/2018 12:15:00 PM      046XX N ELSTON AVE  0890
# ...          ...                     ...                     ...   ...
# 261959  JA385552  08/10/2017 10:30:00 AM         048XX W IOWA ST  1310
# 261960  JA492228  10/30/2017 04:00:00 PM  072XX S SOUTH SHORE DR  0810
# 261961  JA390514  08/13/2017 08:00:00 PM    039XX W VAN BUREN ST  0910
# 261962  JA385930  08/10/2017 04:00:00 AM     071XX S WOLCOTT AVE  1305
# 261963  JA536019  12/02/2017 08:00:00 PM     083XX S INDIANA AVE  1320
#
#         PRIMARY_DESCRIPTION           SECONDARY_DESCRIPTION ARREST DOMESTIC  \
# 0                 NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY      Y        N
# 1                     THEFT                       OVER $500      Y        N
# 2           CRIMINAL DAMAGE                      TO VEHICLE      N        N
# 3                     THEFT                  $500 AND UNDER      N        N
# 4                     THEFT                   FROM BUILDING      N        N
# ...                     ...                             ...    ...      ...
# 261959      CRIMINAL DAMAGE                     TO PROPERTY      N        N
# 261960                THEFT                       OVER $500      N        Y
# 261961  MOTOR VEHICLE THEFT                      AUTOMOBILE      N        N
# 261962      CRIMINAL DAMAGE             CRIMINAL DEFACEMENT      N        N
# 261963      CRIMINAL DAMAGE                      TO VEHICLE      N        N
#
#         BEAT  WARD FBI_CD  X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE  \
# 0       1524  37.0     18     1140136.0     1905903.0  41.897895 -87.760744
# 1       1024  12.0     06     1155313.0     1886555.0  41.844510 -87.705519
# 2        233   5.0     14     1182892.0     1870055.0  41.798635 -87.604823
# 3        311  20.0     06     1178263.0     1863570.0  41.780946 -87.621995
# 4       1722  39.0     06     1146646.0     1930549.0  41.965404 -87.736202
# ...      ...   ...    ...           ...           ...        ...        ...
# 261959  1531  37.0     14     1143912.0     1905538.0  41.896823 -87.746884
# 261960   334   7.0     06     1194878.0     1857803.0  41.764728 -87.561272
# 261961  1132  24.0     07     1150218.0     1897735.0  41.875290 -87.723926
# 261962   735  17.0     14     1164921.0     1857378.0  41.764247 -87.671085
# 261963   632   6.0     14     1179046.0     1849699.0  41.742865 -87.619547
#
#                              LOCATION
# 0       (41.897894893, -87.760743714)
# 1       (41.844510467, -87.705519454)
# 2       (41.798635468, -87.604823241)
# 3       (41.780946398, -87.621995369)
# 4       (41.965404069, -87.736202402)
# ...                               ...
# 261959     (41.8968233, -87.74688383)
# 261960  (41.764728045, -87.561272312)
# 261961  (41.875290412, -87.723926225)
# 261962  (41.764247182, -87.671084615)
# 261963  (41.742865052, -87.619546732)
#
# [261964 rows x 16 columns]

# %%
#Part 5 describing the data that shows the statistical information on the data as seen below
crimesData.describe()
# Out:
#                 BEAT           WARD  X_COORDINATE  Y_COORDINATE  \
# count  261964.000000  261962.000000  2.598360e+05  2.598360e+05
# mean     1144.641558      23.403978  1.165019e+06  1.886737e+06
# std       701.490463      14.185806  1.609511e+04  3.125165e+04
# min       111.000000       1.000000  1.092706e+06  1.813909e+06
# 25%       611.000000      10.000000  1.153404e+06  1.859536e+06
# 50%      1031.000000      24.000000  1.166852e+06  1.894302e+06
# 75%      1723.000000      35.000000  1.176556e+06  1.909030e+06
# max      2535.000000      50.000000  1.205119e+06  1.951535e+06
#
#             LATITUDE      LONGITUDE
# count  259836.000000  259836.000000
# mean       41.844793     -87.669937
# std         0.085941       0.058598
# min        41.644608     -87.934273
# 25%        41.770021     -87.712091
# 50%        41.865716     -87.663540
# 75%        41.906247     -87.627706
# max        42.022671     -87.524529

# %%
#Part 5(i) obtaining the sum of null
crimesData.sum()

# %%
#Part 6
#Select and subsetting primary description using ''
crimesData['PRIMARY_DESCRIPTION']

# %%
#Part 7 
#Obtaining the value counts for PRIMARY_DESCRIPTION column that show the frequency for the values and in descending order
value_counts = crimesData['PRIMARY_DESCRIPTION'].value_counts()
value_counts
# Out:
# THEFT                                63821
# BATTERY                              48917
# CRIMINAL DAMAGE                      28085
# ASSAULT                              19580
# DECEPTIVE PRACTICE                   17672
# OTHER OFFENSE                        16407
# BURGLARY                             12104
# NARCOTICS                            11448
# ROBBERY                              11292
# MOTOR VEHICLE THEFT                  10815
# CRIMINAL TRESPASS                     6881
# WEAPONS VIOLATION                     4867
# OFFENSE INVOLVING CHILDREN            2222
# CRIM SEXUAL ASSAULT                   1515
# PUBLIC PEACE VIOLATION                1427
# INTERFERENCE WITH PUBLIC OFFICER      1151
# SEX OFFENSE                            970
# PROSTITUTION                           649
# HOMICIDE                               627
# ARSON                                  382
# LIQUOR LAW VIOLATION                   207
# KIDNAPPING                             191
# GAMBLING                               180
# STALKING                               168
# INTIMIDATION                           138
# OBSCENITY                               91
# CONCEALED CARRY LICENSE VIOLATION       83
# NON-CRIMINAL                            45
# PUBLIC INDECENCY                        10
# OTHER NARCOTIC VIOLATION                10
# HUMAN TRAFFICKING                        8
# NON-CRIMINAL (SUBJECT SPECIFIED)         1
# Name: PRIMARY_DESCRIPTION, dtype: int64

# %%
#Part 8 selecting two columns  and printing the first 10 items
selected_columns = crimesData[['PRIMARY_DESCRIPTION', 'SECONDARY_DESCRIPTION']]
selected_columns.head(10)
# Out:
#    PRIMARY_DESCRIPTION           SECONDARY_DESCRIPTION
# 0            NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY
# 1                THEFT                       OVER $500
# 2      CRIMINAL DAMAGE                      TO VEHICLE
# 3                THEFT                  $500 AND UNDER
# 4                THEFT                   FROM BUILDING
# 5                ARSON                         BY FIRE
# 6  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 7              ROBBERY  AGGRAVATED VEHICULAR HIJACKING
# 8              BATTERY                          SIMPLE
# 9              ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT

# %%
#Part 8(ii)
#Indexing the data through slicing where the 10th value is not included
crimesData[3:10]
# Out:
#       CASE#       DATE_OF_OCCURENCE                    BLOCK  IUCR  \
# 3  JB245397  04/28/2018 09:00:00 AM     062XX S MICHIGAN AVE  0820
# 4  JB241444  04/28/2018 12:15:00 PM       046XX N ELSTON AVE  0890
# 5  JB241667  04/28/2018 04:28:00 PM      022XX S KENNETH AVE  1020
# 6  JA476742  10/18/2017 11:55:00 PM       006XX N CICERO AVE  0910
# 7  JA509627  11/13/2017 02:35:00 AM   025XX W WELLINGTON AVE  0326
# 8  JB241316  04/28/2018 11:15:00 AM      007XX N DEARBORN ST  0460
# 9  JB241116  04/28/2018 08:50:00 AM  013XX S CALIFORNIA BLVD  0312
#
#    PRIMARY_DESCRIPTION           SECONDARY_DESCRIPTION ARREST DOMESTIC  BEAT  \
# 3                THEFT                  $500 AND UNDER      N        N   311
# 4                THEFT                   FROM BUILDING      N        N  1722
# 5                ARSON                         BY FIRE      N        N  1013
# 6  MOTOR VEHICLE THEFT                      AUTOMOBILE      N        N  1532
# 7              ROBBERY  AGGRAVATED VEHICULAR HIJACKING      N        N  1411
# 8              BATTERY                          SIMPLE      Y        N  1832
# 9              ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT      N        N  1023
#
#    WARD FBI_CD  X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE  \
# 3  20.0     06     1178263.0     1863570.0  41.780946 -87.621995
# 4  39.0     06     1146646.0     1930549.0  41.965404 -87.736202
# 5  22.0     09     1147102.0     1888742.0  41.850673 -87.735597
# 6  28.0     07     1144251.0     1903638.0  41.891603 -87.745687
# 7   1.0     03     1158944.0     1919849.0  41.935799 -87.691280
# 8  42.0    08B     1175802.0     1905458.0  41.895946 -87.629760
# 9  28.0     03     1157906.0     1893450.0  41.863379 -87.695816
#
#                         LOCATION
# 3  (41.780946398, -87.621995369)
# 4  (41.965404069, -87.736202402)
# 5  (41.850672642, -87.735596947)
# 6  (41.891603117, -87.745686519)
# 7  (41.935798543, -87.691279962)
# 8  (41.895945884, -87.629759893)
# 9   (41.863378684, -87.69581565)

# %%
# Part 9
#Extracting the theft values from primary description column using boolean indexing
theft_values = crimesData[crimesData.PRIMARY_DESCRIPTION =='THEFT']
theft_values

# %%
# Part 9(ii)
#Sorting the theft values by date of occurence and printing the first 20 items so i can easily study the data
sorted_theft_values = theft_values.sort_values(by=['DATE_OF_OCCURENCE'],ascending=True)
sorted_theft_values.head(20)
# Out:
#            CASE#       DATE_OF_OCCURENCE                  BLOCK  IUCR  \
# 236262  JB100825  01/01/2018 01:00:00 AM    006XX N FRANKLIN ST  0870
# 143954  JB101281  01/01/2018 01:00:00 AM       004XX N STATE ST  0870
# 240910  JB100870  01/01/2018 01:00:00 AM       004XX N CLARK ST  0890
# 94180   JB125173  01/01/2018 01:00:00 AM       007XX W GRACE ST  0890
# 234598  JB101036  01/01/2018 01:00:00 AM     003XX N WABASH AVE  0890
# 203541  JB100087  01/01/2018 01:25:00 AM  048XX N FRANCISCO AVE  0820
# 66428   JB100657  01/01/2018 01:27:00 PM  023XX W GRANVILLE AVE  0820
# 237411  JB100234  01/01/2018 01:30:00 AM    011XX N ASHLAND AVE  0810
# 191899  JB100647  01/01/2018 01:38:00 PM       0000X N STATE ST  0860
# 230606  JB100466  01/01/2018 01:45:00 AM      0000X W KINZIE ST  0870
# 140865  JB100393  01/01/2018 02:00:00 AM     001XX W HUBBARD ST  0890
# 145417  JB124888  01/01/2018 02:00:00 AM    022XX N LINCOLN AVE  0890
# 238087  JB100879  01/01/2018 02:00:00 AM       003XX N STATE ST  0890
# 110657  JB117126  01/01/2018 02:00:00 PM    022XX W MC LEAN AVE  0820
# 191453  JB100685  01/01/2018 02:30:00 AM  012XX N MILWAUKEE AVE  0810
# 147961  JB100734  01/01/2018 02:30:00 PM      044XX W THOMAS ST  0810
# 80640   JB100669  01/01/2018 03:00:00 AM   006XX S MICHIGAN AVE  0890
# 139400  JB101421  01/01/2018 03:00:00 AM      018XX W NORTH AVE  0810
# 127254  JB100785  01/01/2018 03:00:00 PM     001XX E ONTARIO ST  0890
# 51076   JB142078  01/01/2018 03:00:00 PM    029XX W FILLMORE ST  0820
#
#        PRIMARY_DESCRIPTION SECONDARY_DESCRIPTION ARREST DOMESTIC  BEAT  WARD  \
# 236262               THEFT        POCKET-PICKING      N        N  1831  42.0
# 143954               THEFT        POCKET-PICKING      N        N  1831  42.0
# 240910               THEFT         FROM BUILDING      N        N  1831  42.0
# 94180                THEFT         FROM BUILDING      N        N  1925  46.0
# 234598               THEFT         FROM BUILDING      N        N  1834  42.0
# 203541               THEFT        $500 AND UNDER      Y        N  2031  40.0
# 66428                THEFT        $500 AND UNDER      N        Y  2413  50.0
# 237411               THEFT             OVER $500      N        N  1213   1.0
# 191899               THEFT          RETAIL THEFT      N        N   112  42.0
# 230606               THEFT        POCKET-PICKING      N        N  1831  42.0
# 140865               THEFT         FROM BUILDING      N        N  1831  42.0
# 145417               THEFT         FROM BUILDING      N        N  1812  43.0
# 238087               THEFT         FROM BUILDING      N        N  1831  42.0
# 110657               THEFT        $500 AND UNDER      N        N  1432  32.0
# 191453               THEFT             OVER $500      N        N  1424   1.0
# 147961               THEFT             OVER $500      N        N  1111  37.0
# 80640                THEFT         FROM BUILDING      N        N   123   2.0
# 139400               THEFT             OVER $500      N        N  1424   1.0
# 127254               THEFT         FROM BUILDING      N        N  1834  42.0
# 51076                THEFT        $500 AND UNDER      N        N  1135  28.0
#
#        FBI_CD  X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE  \
# 236262     06     1174211.0     1904618.0  41.893677 -87.635628
# 143954     06     1176292.0     1903437.0  41.890389 -87.628021
# 240910     06     1175463.0     1903198.0  41.889752 -87.631073
# 94180      06     1170516.0     1925645.0  41.951457 -87.648582
# 234598     06     1176556.0     1902666.0  41.888267 -87.627075
# 203541     06     1156348.0     1932071.0  41.969389 -87.700489
# 66428      06     1159719.0     1941110.0  41.994124 -87.687843
# 237411     06     1165520.0     1907603.0  41.902057 -87.667462
# 191899     06     1176365.0     1900502.0  41.882334 -87.627842
# 230606     06     1175769.0     1903009.0  41.889226 -87.629955
# 140865     06     1175290.0     1903292.0  41.890014 -87.631705
# 145417     06     1171576.0     1915192.0  41.922751 -87.644994
# 238087     06     1176295.0     1902702.0  41.888372 -87.628032
# 110657     06     1161123.0     1913529.0  41.918411 -87.683448
# 191453     06     1165414.0     1908391.0  41.904222 -87.667829
# 147961     06     1146590.0     1906959.0  41.900672 -87.737012
# 80640      06     1177377.0     1897431.0  41.873884 -87.624219
# 139400     06     1163678.0     1910679.0  41.910537 -87.674141
# 127254     06     1177526.0     1904526.0  41.893349 -87.623456
# 51076      06     1156739.0     1895231.0  41.868290 -87.700051
#
#                              LOCATION
# 236262  (41.893676531, -87.635628328)
# 143954  (41.890389116, -87.628021263)
# 240910  (41.889751946, -87.631072891)
# 94180   (41.951457303, -87.648582038)
# 234598  (41.888267493, -87.627075047)
# 203541   (41.96938944, -87.700488807)
# 66428   (41.994123845, -87.687843134)
# 237411  (41.902057081, -87.667462159)
# 191899   (41.88233367, -87.627841791)
# 230606  (41.889226442, -87.629954828)
# 140865  (41.890013771, -87.631705393)
# 145417  (41.922750548, -87.644994062)
# 238087   (41.88837217, -87.628032433)
# 110657  (41.918410984, -87.683448012)
# 191453  (41.904221664, -87.667829056)
# 147961  (41.900672024, -87.737011585)
# 80640   (41.873883785, -87.624218932)
# 139400   (41.910536878, -87.67414124)
# 127254  (41.893349463, -87.623456403)
# 51076   (41.868289635, -87.700051402)

# %%
#Part 10
#Group by year and month to look at data
grouped = crimesData.groupby([crimesData.DATE_OF_OCCURENCE])
grouped

# %% [markdown]
# ## Question 2
#
# (a). What is the standard deviation of the data:
#
# $$ 1, 3, 1, 2,9, 4, 5, 6, 10, 4 $$
#
# **Note** Use 1 degree of freedom in the denominator.
#
#
# (b). Importing all relevant libraries
#
# `import pandas as pd, import numpy as np
# import matplotlib.pyplot as plt
# plt.style.use('ggplot')
# import math
# import requests
# from bs4 import BeautifulSoup
# from selenium import webdriver
# import datetime
# import dateutil.parser
# import time
# import re
# import statsmodels.api as sm
# import statsmodels.formula.api as smf
# import sklearn
# from tqdm import tqdm_notebook
# pd.options.mode.chained_assignment = None`.
#
# Following the same format of code below:
#
# `team_converter = pd.read_csv("source_files/team_converter.csv",encoding="cp1252")
# big_five_league_fixtures = pd.read_csv("source_files/big_five_league_fixtures.csv")
# big_five_league_fixtures["date"] = big_five_league_fixtures["date"].apply(lambda x:datetime.datetime.strptime(x,"%d/%m/%Y").date())
# big_five_league_fixtures["home_points"] = big_five_league_fixtures["result"].map({"H":3,"D":1,"A":0})
# big_five_league_fixtures["away_points"] = big_five_league_fixtures["result"].map({"A":3,"D":1,"H":0})`
#
# `FIFA_league_season_teams_df = pd.read_csv("output_files/FIFA_league_season_teams_df.csv")
# FIFA_team_season_players_df = pd.read_csv("output_files/FIFA_team_season_players_df.csv")
# TM_team_managers_df = pd.read_csv("output_files/TM_team_managers_df.csv")`
#
# import and load all files as specified in the code
#
# b).
#
# (i). Run the code and adjust appropriate file paths to import and convert the dataset into proper format.
#
# (ii). Join the team ids onto fixture data. HINT: Using the same conversion and format of this exmple : First line of code `FIFA_edition_dict = {
#     "FIFA 2005":["08/10/2004","/fifa05_1/"],.....}` to complete all the joins for all years.
#
# (iii). Join Manager tenure onto fixture data.
#
# (iv). Join expected points onto fixture data.
#
# (v). Create dataframe of each team's performance in each season
#
# (vi). Create dataframe of each manager tenure, with past and future performance

# %% [markdown]
# ## Question 3
#
# (a). Load the covid-19 dataset in the CSV file `COVID-19 Cases.csv`, set the column `date` as the index, and ensure that `date` is a `DateTimeIndex`. Print a view of first 10 lines of the dataset. Next we will isolate the data we want to focus our attention on by creating a new DataFrame from the source, and by applying a few filters against it. We want to isolate the records where all the following conditions are true. First the Daily Difference count is greater than zero. Next the Case Type should be Confirmed. Finally, the Country_Region should be only Italy: Check whether the results are sorted by cases & ascending order to  well and accordingly, write the command to accomplish it:
#
# (b). Now lets visually display the distribution of the values in the Difference column. We can pass an array of values into the default hist() plot (`plot the histogram using the Difference Column`):
#
# (c). Obtain descriptive and inferential statics on at least three columns & create a new DataFrame out of the three columns computed statistics on.
#
# (d). Obtain a boxplot of the selected number of columns of your choice in the dataset. Interprete the resulting chart (boxplot) to make meaning out of it.

# %%
#Part a
#Importing the data and coverting the date into datetime series and setting it as an index using parse_dates=['Date'], index_col=['Date']
covid_data = pd.read_csv(r"C:\Users\golden\Desktop\ds\Final Data Science Exam\COVID-19 Cases.csv",parse_dates=['Date'], index_col=['Date'])
covid_data
# Out:
#            Country_Region Province_State  Difference     Prep_Flow_Runtime  \
# Date
# 2020-03-09          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-08          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-07          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-06          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-05          India            NaN           0  3/24/2020 9:39:03 AM
# ...                   ...            ...         ...                   ...
# 2020-01-27          Syria            NaN           0  3/24/2020 9:39:03 AM
# 2020-01-26          Syria            NaN           0  3/24/2020 9:39:03 AM
# 2020-01-25          Syria            NaN           0  3/24/2020 9:39:03 AM
# 2020-01-24          Syria            NaN           0  3/24/2020 9:39:03 AM
# 2020-01-23          Syria            NaN           0  3/24/2020 9:39:03 AM
#
#            Latest_Date  Case_Type  Cases        Lat       Long
# Date
# 2020-03-09   3/23/2020     Deaths      0  21.000000  78.000000
# 2020-03-08   3/23/2020     Deaths      0  21.000000  78.000000
# 2020-03-07   3/23/2020     Deaths      0  21.000000  78.000000
# 2020-03-06   3/23/2020     Deaths      0  21.000000  78.000000
# 2020-03-05   3/23/2020     Deaths      0  21.000000  78.000000
# ...                ...        ...    ...        ...        ...
# 2020-01-27   3/23/2020  Confirmed      0  34.802075  38.996815
# 2020-01-26   3/23/2020  Confirmed      0  34.802075  38.996815
# 2020-01-25   3/23/2020  Confirmed      0  34.802075  38.996815
# 2020-01-24   3/23/2020  Confirmed      0  34.802075  38.996815
# 2020-01-23   3/23/2020  Confirmed      0  34.802075  38.996815
#
# [35502 rows x 9 columns]

# %%
#Using the info method for confirmation, as it shows the datetimeindex entries for the date column

# %%
#Part a(ii)
#Coverted the date to datetime series and set it as the column index using parse_dates=['Date'], index_col=['Date'] while loading my dataframe
# and confirming that its a datatime series using the info() function
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35502 entries, 2020-03-09 to 2020-01-23
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country_Region     35502 non-null  object
#  1   Province_State     15616 non-null  object
#  2   Difference         35502 non-null  int64
#  3   Prep_Flow_Runtime  35502 non-null  object
#  4   Latest_Date        35502 non-null  object
#  5   Case_Type          35502 non-null  object
#  6   Cases              35502 non-null  int64
#  7   Lat                35136 non-null  float64
#  8   Long               35136 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.7+ MB

# %%
#Part a(iii)
#Printing the first 10 using the head method and passing the value 10 as an argument
covid_data.head(10)
# Out:
#            Country_Region Province_State  Difference     Prep_Flow_Runtime  \
# Date
# 2020-03-09          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-08          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-07          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-06          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-05          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-04          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-03          India            NaN           0  3/24/2020 9:39:03 AM
# 2020-03-23          India            NaN           3  3/24/2020 9:39:03 AM
# 2020-03-22          India            NaN           3  3/24/2020 9:39:03 AM
# 2020-03-21          India            NaN          -1  3/24/2020 9:39:03 AM
#
#            Latest_Date Case_Type  Cases   Lat  Long
# Date
# 2020-03-09   3/23/2020    Deaths      0  21.0  78.0
# 2020-03-08   3/23/2020    Deaths      0  21.0  78.0
# 2020-03-07   3/23/2020    Deaths      0  21.0  78.0
# 2020-03-06   3/23/2020    Deaths      0  21.0  78.0
# 2020-03-05   3/23/2020    Deaths      0  21.0  78.0
# 2020-03-04   3/23/2020    Deaths      0  21.0  78.0
# 2020-03-03   3/23/2020    Deaths      0  21.0  78.0
# 2020-03-23   3/23/2020    Deaths     10  21.0  78.0
# 2020-03-22   3/23/2020    Deaths      7  21.0  78.0
# 2020-03-21   3/23/2020    Deaths      4  21.0  78.0

# %%
#Part a(iv)
#Data filtering for confirmed type in Italy and with a difference greater than 0 using boolean indexing using variable filtered_results
filtered_results = covid_data[(covid_data.Difference >0) & (covid_data.Case_Type == 'Confirmed') & (covid_data.Country_Region == 'Italy')]
filtered_results
# Out:
#            Country_Region Province_State  Difference     Prep_Flow_Runtime  \
# Date
# 2020-03-09          Italy            NaN        1797  3/24/2020 9:39:03 AM
# 2020-03-08          Italy            NaN        1492  3/24/2020 9:39:03 AM
# 2020-03-07          Italy            NaN        1247  3/24/2020 9:39:03 AM
# 2020-03-06          Italy            NaN         778  3/24/2020 9:39:03 AM
# 2020-03-05          Italy            NaN         769  3/24/2020 9:39:03 AM
# 2020-03-04          Italy            NaN         587  3/24/2020 9:39:03 AM
# 2020-03-03          Italy            NaN         466  3/24/2020 9:39:03 AM
# 2020-03-23          Italy            NaN        4789  3/24/2020 9:39:03 AM
# 2020-03-22          Italy            NaN        5560  3/24/2020 9:39:03 AM
# 2020-03-21          Italy            NaN        6557  3/24/2020 9:39:03 AM
# 2020-03-20          Italy            NaN        5986  3/24/2020 9:39:03 AM
# 2020-03-02          Italy            NaN         342  3/24/2020 9:39:03 AM
# 2020-03-19          Italy            NaN        5322  3/24/2020 9:39:03 AM
# 2020-03-18          Italy            NaN        4207  3/24/2020 9:39:03 AM
# 2020-03-17          Italy            NaN        3526  3/24/2020 9:39:03 AM
# 2020-03-16          Italy            NaN        3233  3/24/2020 9:39:03 AM
# 2020-03-15          Italy            NaN        3590  3/24/2020 9:39:03 AM
# 2020-03-14          Italy            NaN        3497  3/24/2020 9:39:03 AM
# 2020-03-13          Italy            NaN        5198  3/24/2020 9:39:03 AM
# 2020-03-11          Italy            NaN        2313  3/24/2020 9:39:03 AM
# 2020-03-10          Italy            NaN         977  3/24/2020 9:39:03 AM
# 2020-03-01          Italy            NaN         566  3/24/2020 9:39:03 AM
# 2020-02-07          Italy            NaN           1  3/24/2020 9:39:03 AM
# 2020-02-29          Italy            NaN         240  3/24/2020 9:39:03 AM
# 2020-02-28          Italy            NaN         233  3/24/2020 9:39:03 AM
# 2020-02-27          Italy            NaN         202  3/24/2020 9:39:03 AM
# 2020-02-26          Italy            NaN         131  3/24/2020 9:39:03 AM
# 2020-02-25          Italy            NaN          93  3/24/2020 9:39:03 AM
# 2020-02-24          Italy            NaN          74  3/24/2020 9:39:03 AM
# 2020-02-23          Italy            NaN          93  3/24/2020 9:39:03 AM
# 2020-02-22          Italy            NaN          42  3/24/2020 9:39:03 AM
# 2020-02-21          Italy            NaN          17  3/24/2020 9:39:03 AM
# 2020-01-31          Italy            NaN           2  3/24/2020 9:39:03 AM
#
#            Latest_Date  Case_Type  Cases   Lat  Long
# Date
# 2020-03-09   3/23/2020  Confirmed   9172  43.0  12.0
# 2020-03-08   3/23/2020  Confirmed   7375  43.0  12.0
# 2020-03-07   3/23/2020  Confirmed   5883  43.0  12.0
# 2020-03-06   3/23/2020  Confirmed   4636  43.0  12.0
# 2020-03-05   3/23/2020  Confirmed   3858  43.0  12.0
# 2020-03-04   3/23/2020  Confirmed   3089  43.0  12.0
# 2020-03-03   3/23/2020  Confirmed   2502  43.0  12.0
# 2020-03-23   3/23/2020  Confirmed  63927  43.0  12.0
# 2020-03-22   3/23/2020  Confirmed  59138  43.0  12.0
# 2020-03-21   3/23/2020  Confirmed  53578  43.0  12.0
# 2020-03-20   3/23/2020  Confirmed  47021  43.0  12.0
# 2020-03-02   3/23/2020  Confirmed   2036  43.0  12.0
# 2020-03-19   3/23/2020  Confirmed  41035  43.0  12.0
# 2020-03-18   3/23/2020  Confirmed  35713  43.0  12.0
# 2020-03-17   3/23/2020  Confirmed  31506  43.0  12.0
# 2020-03-16   3/23/2020  Confirmed  27980  43.0  12.0
# 2020-03-15   3/23/2020  Confirmed  24747  43.0  12.0
# 2020-03-14   3/23/2020  Confirmed  21157  43.0  12.0
# 2020-03-13   3/23/2020  Confirmed  17660  43.0  12.0
# 2020-03-11   3/23/2020  Confirmed  12462  43.0  12.0
# 2020-03-10   3/23/2020  Confirmed  10149  43.0  12.0
# 2020-03-01   3/23/2020  Confirmed   1694  43.0  12.0
# 2020-02-07   3/23/2020  Confirmed      3  43.0  12.0
# 2020-02-29   3/23/2020  Confirmed   1128  43.0  12.0
# 2020-02-28   3/23/2020  Confirmed    888  43.0  12.0
# 2020-02-27   3/23/2020  Confirmed    655  43.0  12.0
# 2020-02-26   3/23/2020  Confirmed    453  43.0  12.0
# 2020-02-25   3/23/2020  Confirmed    322  43.0  12.0
# 2020-02-24   3/23/2020  Confirmed    229  43.0  12.0
# 2020-02-23   3/23/2020  Confirmed    155  43.0  12.0
# 2020-02-22   3/23/2020  Confirmed     62  43.0  12.0
# 2020-02-21   3/23/2020  Confirmed     20  43.0  12.0
# 2020-01-31   3/23/2020  Confirmed      2  43.0  12.0

# %%
#Sorting the values by cases in ascending order using sort values method
filtered_results.sort_values(by=['Cases'],ascending=True)
# Out:
#            Country_Region Province_State  Difference     Prep_Flow_Runtime  \
# Date
# 2020-01-31          Italy            NaN           2  3/24/2020 9:39:03 AM
# 2020-02-07          Italy            NaN           1  3/24/2020 9:39:03 AM
# 2020-02-21          Italy            NaN          17  3/24/2020 9:39:03 AM
# 2020-02-22          Italy            NaN          42  3/24/2020 9:39:03 AM
# 2020-02-23          Italy            NaN          93  3/24/2020 9:39:03 AM
# 2020-02-24          Italy            NaN          74  3/24/2020 9:39:03 AM
# 2020-02-25          Italy            NaN          93  3/24/2020 9:39:03 AM
# 2020-02-26          Italy            NaN         131  3/24/2020 9:39:03 AM
# 2020-02-27          Italy            NaN         202  3/24/2020 9:39:03 AM
# 2020-02-28          Italy            NaN         233  3/24/2020 9:39:03 AM
# 2020-02-29          Italy            NaN         240  3/24/2020 9:39:03 AM
# 2020-03-01          Italy            NaN         566  3/24/2020 9:39:03 AM
# 2020-03-02          Italy            NaN         342  3/24/2020 9:39:03 AM
# 2020-03-03          Italy            NaN         466  3/24/2020 9:39:03 AM
# 2020-03-04          Italy            NaN         587  3/24/2020 9:39:03 AM
# 2020-03-05          Italy            NaN         769  3/24/2020 9:39:03 AM
# 2020-03-06          Italy            NaN         778  3/24/2020 9:39:03 AM
# 2020-03-07          Italy            NaN        1247  3/24/2020 9:39:03 AM
# 2020-03-08          Italy            NaN        1492  3/24/2020 9:39:03 AM
# 2020-03-09          Italy            NaN        1797  3/24/2020 9:39:03 AM
# 2020-03-10          Italy            NaN         977  3/24/2020 9:39:03 AM
# 2020-03-11          Italy            NaN        2313  3/24/2020 9:39:03 AM
# 2020-03-13          Italy            NaN        5198  3/24/2020 9:39:03 AM
# 2020-03-14          Italy            NaN        3497  3/24/2020 9:39:03 AM
# 2020-03-15          Italy            NaN        3590  3/24/2020 9:39:03 AM
# 2020-03-16          Italy            NaN        3233  3/24/2020 9:39:03 AM
# 2020-03-17          Italy            NaN        3526  3/24/2020 9:39:03 AM
# 2020-03-18          Italy            NaN        4207  3/24/2020 9:39:03 AM
# 2020-03-19          Italy            NaN        5322  3/24/2020 9:39:03 AM
# 2020-03-20          Italy            NaN        5986  3/24/2020 9:39:03 AM
# 2020-03-21          Italy            NaN        6557  3/24/2020 9:39:03 AM
# 2020-03-22          Italy            NaN        5560  3/24/2020 9:39:03 AM
# 2020-03-23          Italy            NaN        4789  3/24/2020 9:39:03 AM
#
#            Latest_Date  Case_Type  Cases   Lat  Long
# Date
# 2020-01-31   3/23/2020  Confirmed      2  43.0  12.0
# 2020-02-07   3/23/2020  Confirmed      3  43.0  12.0
# 2020-02-21   3/23/2020  Confirmed     20  43.0  12.0
# 2020-02-22   3/23/2020  Confirmed     62  43.0  12.0
# 2020-02-23   3/23/2020  Confirmed    155  43.0  12.0
# 2020-02-24   3/23/2020  Confirmed    229  43.0  12.0
# 2020-02-25   3/23/2020  Confirmed    322  43.0  12.0
# 2020-02-26   3/23/2020  Confirmed    453  43.0  12.0
# 2020-02-27   3/23/2020  Confirmed    655  43.0  12.0
# 2020-02-28   3/23/2020  Confirmed    888  43.0  12.0
# 2020-02-29   3/23/2020  Confirmed   1128  43.0  12.0
# 2020-03-01   3/23/2020  Confirmed   1694  43.0  12.0
# 2020-03-02   3/23/2020  Confirmed   2036  43.0  12.0
# 2020-03-03   3/23/2020  Confirmed   2502  43.0  12.0
# 2020-03-04   3/23/2020  Confirmed   3089  43.0  12.0
# 2020-03-05   3/23/2020  Confirmed   3858  43.0  12.0
# 2020-03-06   3/23/2020  Confirmed   4636  43.0  12.0
# 2020-03-07   3/23/2020  Confirmed   5883  43.0  12.0
# 2020-03-08   3/23/2020  Confirmed   7375  43.0  12.0
# 2020-03-09   3/23/2020  Confirmed   9172  43.0  12.0
# 2020-03-10   3/23/2020  Confirmed  10149  43.0  12.0
# 2020-03-11   3/23/2020  Confirmed  12462  43.0  12.0
# 2020-03-13   3/23/2020  Confirmed  17660  43.0  12.0
# 2020-03-14   3/23/2020  Confirmed  21157  43.0  12.0
# 2020-03-15   3/23/2020  Confirmed  24747  43.0  12.0
# 2020-03-16   3/23/2020  Confirmed  27980  43.0  12.0
# 2020-03-17   3/23/2020  Confirmed  31506  43.0  12.0
# 2020-03-18   3/23/2020  Confirmed  35713  43.0  12.0
# 2020-03-19   3/23/2020  Confirmed  41035  43.0  12.0
# 2020-03-20   3/23/2020  Confirmed  47021  43.0  12.0
# 2020-03-21   3/23/2020  Confirmed  53578  43.0  12.0
# 2020-03-22   3/23/2020  Confirmed  59138  43.0  12.0
# 2020-03-23   3/23/2020  Confirmed  63927  43.0  12.0

# %%
#Part B plotting the histogram using the Difference Column which is passed as an argument for a single column
covid_data.hist(column='Difference');

# %%
#Part C, Data Description to look at the statistics of the dataframe
covid_data.describe()
# Out:
#          Difference         Cases           Lat          Long
# count  35502.000000  35502.000000  35136.000000  35136.000000
# mean      11.103994    162.593460     25.062739      5.678952
# std      167.771676   2442.608235     23.437435     79.280423
# min      -62.000000      0.000000    -41.454500   -157.678350
# 25%        0.000000      0.000000     12.448525    -70.492000
# 50%        0.000000      0.000000     31.370375     11.221450
# 75%        0.000000      1.000000     42.006025     59.271325
# max    14840.000000  67800.000000     71.706900    178.065000

# %%
#New dataFrame, let it be new_df for columns difference, cases and lat
new_df = covid_data[['Difference','Cases','Lat']]
new_df
# Out:
#             Difference  Cases        Lat
# Date
# 2020-03-09           0      0  21.000000
# 2020-03-08           0      0  21.000000
# 2020-03-07           0      0  21.000000
# 2020-03-06           0      0  21.000000
# 2020-03-05           0      0  21.000000
# ...                ...    ...        ...
# 2020-01-27           0      0  34.802075
# 2020-01-26           0      0  34.802075
# 2020-01-25           0      0  34.802075
# 2020-01-24           0      0  34.802075
# 2020-01-23           0      0  34.802075
#
# [35502 rows x 3 columns]

# %%
#Boxplot for columns difference, cases and lat
boxplot = covid_data.boxplot(column=['Difference', 'Cases', 'Lat'])

# %% [markdown]
# ## Question 4
#
# (a). Write the function `QUESTION_20` that will take a single input `s`, which is a string
# and will return a Series that counts the number of times each letter in `s` appears in `s`
# _without_ regard to case. Do not include spaces.  Ensure the Series returned as its index sorted.
#
# **Hints**:
#
# * Have a look at `value_counts` for a pandas `Series`.
# * You can iterate across the letters of a string using
#
# ```
# some_string = 'abcdefg'
# for letter in some_string:
#     do somethign with letter...
# ```
# * `str.lower` can be used to get the lower case version of a string
#
# (b). Use binary ufuncs, to do some interesting aggregates that can be computed directly from the object.
# For example, if we'd like to *reduce* an array with a particular operation, we can use the ``reduce`` method of any ufunc.
# A reduce repeatedly applies a given operation to the elements of an array until only a single result remains.
#
# For example, calling ``reduce`` on the ``add`` ufunc returns the sum of all elements in the array: `For x = np.arange(1, 6)`
#
# (i). reduce `x`
#
# (ii). add `x`
#
# (iii). multiply `x`
#
# (iv). accumulate `x`
#
# (v). compute additiona and accumulation in one row `x`
#
# (vi). compute multiplication and accumulation in one row `x`
#
# (V). do an outer product of `x`

# %%
#Part a, function to count the number of times each letter appears in a string using pandas value counts that returns the frequency for each letter
#let the string s be datascienceexam
s = "datascienceexam"
def QUESTION_20(s):
    
    print(pd.Series(list(s)).value_counts())
          
#calling the function QUESTION_20()         
QUESTION_20(s)

# %%
#Part b, displaying the arra
x = np.arange(1, 6)
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
#(i). reduce x,reduction using addittion to a single value
np.add.reduce(x, dtype = int, axis = 0)
# Out:
# 15

# %%
#(iii)Multiplying x by x as the second parameter
np.multiply(x,x)
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
#(iv). accumulate x with addition
np.add.accumulate(x, axis = 0)
# Out:
# array([ 1,  3,  6, 10, 15], dtype=int32)

# %%
# computing addition and accumulation in one row for x
np.add.accumulate(x)
# Out:
# array([ 1,  3,  6, 10, 15], dtype=int32)

# %%
#(vi)Computing multiplication and accumulation in one row for  x
np.multiply.accumulate(x, axis = 0)
# Out:
# array([  1,   2,   6,  24, 120], dtype=int32)

# %%
#(V). do an outer product of x using x as the b parameter
np.outer(x,x)
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [ 2,  4,  6,  8, 10],
#        [ 3,  6,  9, 12, 15],
#        [ 4,  8, 12, 16, 20],
#        [ 5, 10, 15, 20, 25]])

# %% [markdown]
# GOOD LUCK & `Be Not afraid of going slowly, be afraid of standing still` Old Chineese proverb
